# %%
# modules importation
from trends_functions import *
from warnings import filterwarnings
filterwarnings('ignore')

# %%
# computation parameters
params = get_params()

# %%
# run observations
# 'ang4487aer' 'od550aer' 'od550gt1aer' 'od550lt1aer' 'concpm10' 'concpm25' 'concso4' 'scatc550dryaer' 'absc550aer'
var = 'od550aer'
params['kind'] = 'obs'
fill_params(params, var)
params['period'] = '1850-2018'
params['var'] = var
obs_source = params['source']
params['min_dobs']=0 #300
reader = pya.io.ReadUngridded(obs_source)
obs_data = reader.read(vars_to_retrieve=var)

# %%
_, OBS_MAP, OBS_DF = process_trend(
    obs_data, params,
    plot=False, show_plot=False, save_plot=False, write_json=False
)
# Out:
# no flags
# no flags EUROPE station:  ZvenigoroddsEi_GCWD
# no flags ASIA station:  Zhongshan_UnivityDh
# no flags NAMERICA station:  Yumaowknife_AuroraC
# no flags SAMERICA station:  Veracruz_MAX_MEXFOP
# no flags NAFRICA station:  Zinder_DMNporttutea
# region:  SAFRICA station:  Walvis_Bay_airport
# Less than 7 points in selected period
# no flags
# no flags AUSTRALIA station:  Tinga_Tinganand_QLD
# region:  WORLD station:  ZvenigorodportityaP

# %%
MOD_MAP, MOD_DF = {}, {}

# run models
#'GFDL-AM4-amip_HIST' if var == 'od550lt1aer' || var == 'od550gt1aer' || 
mod_var = var
params['kind'] = 'mod'

all_mods = list(get_all_mods().keys())

#for the models, set mon_dim to zero
params['min_dim'] = 0
#params['min_ntrend'] = 4
mod_var = params['mod_var']

#mod_sources = sources[var]
mod_sources = params['models']

for mod_source in mod_sources:
    params['source'] = mod_source
    
    #check if model in cache
    fn = 'cache/'+mod_source+'_'+var+'.pkl'
    if os.path.isfile(fn):
        print(mod_source,'use pickle')
        # for reading also binary mode is important 
        pklfile = open(fn, 'rb')      
        mod_data = pickle.load(pklfile) 
        pklfile.close()
    else:
        print(mod_source,'read netcdf data')
        reader = pya.io.ReadGridded(mod_source)
        if (var=='scatc550dryaer'):
            mod_data = reader.read_var(mod_var, ts_type='daily', aux_fun=pya.io.aux_read_cubes.subtract_cubes, aux_vars=['ec550dryaer', 'absc550aer'])
        else:
            mod_data = reader.read_var(mod_var, ts_type='daily')
        
        #if cube has 4 dimensions, extract first level
        if mod_var in ['concso4', 'concpm10', 'concpm25', 'scatc550dryaer', 'absc550aer'] and len(np.shape(mod_data))==4:
            print('cube has 4 dimension, extract first layer')
            mod_data = mod_data.extract_surface_level()
        
        mod_data = mod_data.resample_time(to_ts_type='monthly')

        #write picke file in cache directory
        pklfile = open(fn, 'ab') 

        try:
            # source, destination 
            pickle.dump(mod_data, pklfile)                      
            pklfile.close()
        except AttributeError:
            print('AttributeError')
            os.remove(fn)

    if type(mod_data)==float:
        MOD_MAP[mod_source] = {}
    else:
        #crop the cube to interest period, so can handle WORLD region
        mod_data = mod_data.crop(time_range=(params['period'].split('-')[0], str(int(params['period'].split('-')[1])+1)))
        #check time frequency, if 5 years, set #params['min_ntrend'] = 0
        years = [ts.item().year for ts in mod_data.time_stamps()]
        uyears = np.unique(years)
        i2000 = np.argmin(abs(uyears-2000))
        dy = uyears[i2000+1]-uyears[i2000]
        if dy>1:
            params['min_ntrend'] = 4
        else:
            params['min_ntrend'] = 7
        
        #full colocation
        _, MOD_MAP[mod_source], MOD_DF[mod_source], = process_trend(
            mod_data, params, obs=obs_data,
            colocate_time=False, colocate_space=False,
            OBS_DF = OBS_DF,
            plot=False, show_plot=False, save_plot=False, write_json=False
        )
# Out:
# ECMWF_CAMS_REAN use pickle
# OsloCTM3v1.01-met2010_AP3-HIST use pickle
# NorESM2-CPL-NEWTEST_HIST use pickle
# GFDL-AM4-amip_HIST use pickle
# CanESM5_historical use pickle
# CESM2_historical use pickle
# IPSL-CM6A-LR_historical use pickle
# GEOS-i33p2_HIST use pickle
# ECHAM6.3-HAM2.3-fSST_HIST use pickle
# BCC-CUACE_AP3-HIST use pickle
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-61-fa3015b414d2> in <module>
#      73             colocate_time=False, colocate_space=False,
#      74             OBS_DF = OBS_DF,
# ---> 75             plot=False, show_plot=False, save_plot=False, write_json=False
#      76         )
#
# ~/Dev/pyaerocom/trends/scripts/trends_functions.py in process_trend(data, params, obs, colocate_time, colocate_space, OBS_DF, plot, write_json, show_plot, save_plot)
#    1063             else:
#    1064                 data_all = f(data)
# -> 1065                 med_area = data_all.get_area_weighted_timeseries()
#    1066                 npoints = np.shape(data_all.cube.data)[1]*np.shape(data_all.cube.data)[2]
#    1067         # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ~/Dev/pyaerocom/pyaerocom/pyaerocom/griddeddata.py in get_area_weighted_timeseries(self, region)
#    1701         else:
#    1702             d = self
# -> 1703         vals = d.area_weighted_mean()
#    1704
#    1705         stat[self.var_name] = Series(vals, d.time_stamps())
#
# ~/Dev/pyaerocom/pyaerocom/pyaerocom/griddeddata.py in area_weighted_mean(self)
#    2185         return self.collapsed(coords=["longitude", "latitude"],
#    2186                               aggregator=MEAN,
# -> 2187                               weights=ws).grid.data
#    2188
#    2189     def mean(self, areaweighted=True):
#
# ~/Dev/pyaerocom/pyaerocom/pyaerocom/griddeddata.py in collapsed(self, coords, aggregator, **kwargs)
#    2018         if isinstance(aggregator, str):
#    2019             aggregator = str_to_iris(aggregator)
# -> 2020         collapsed = self.grid.collapsed(coords, aggregator, **kwargs)
#    2021         return GriddedData(collapsed, **self.cube.attributes)
#    2022
#
# ~/anaconda3/envs/pya/lib/python3.7/site-packages/iris/cube.py in collapsed(self, coords, aggregator, **kwargs)
#    3271             new_shape = untouched_shape + [end_size]
#    3272             dims = untouched_dims + dims_to_collapse
# -> 3273             unrolled_data = np.transpose(self.data, dims).reshape(new_shape)
#    3274
#    3275             # Perform the same operation on the weights if applicable
#
# ~/anaconda3/envs/pya/lib/python3.7/site-packages/iris/cube.py in data(self)
#    1690
#    1691         """
# -> 1692         return self._data_manager.data
#    1693
#    1694     @data.setter
#
# ~/anaconda3/envs/pya/lib/python3.7/site-packages/iris/_data_manager.py in data(self)
#     214             try:
#     215                 # Realise the lazy data.
# --> 216                 result = as_concrete_data(self._lazy_array)
#     217                 # Assign the realised result.
#     218                 self._real_array = result
#
# ~/anaconda3/envs/pya/lib/python3.7/site-packages/iris/_lazy_data.py in as_concrete_data(data)
#     169     """
#     170     if is_lazy_data(data):
# --> 171         data, = _co_realise_lazy_arrays([data])
#     172
#     173     return data
#
# ~/anaconda3/envs/pya/lib/python3.7/site-packages/iris/_lazy_data.py in _co_realise_lazy_arrays(arrays)
#     133
#     134     """
# --> 135     computed_arrays = da.compute(*arrays)
#     136     results = []
#     137     for lazy_in, real_out in zip(arrays, computed_arrays):
#
# ~/anaconda3/envs/pya/lib/python3.7/site-packages/dask/base.py in compute(*args, **kwargs)
#     434     keys = [x.__dask_keys__() for x in collections]
#     435     postcomputes = [x.__dask_postcompute__() for x in collections]
# --> 436     results = schedule(dsk, keys, **kwargs)
#     437     return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#     438
#
# ~/anaconda3/envs/pya/lib/python3.7/site-packages/dask/threaded.py in get(dsk, result, cache, num_workers, pool, **kwargs)
#      78         get_id=_thread_get_id,
#      79         pack_exception=pack_exception,
# ---> 80         **kwargs
#      81     )
#      82
#
# ~/anaconda3/envs/pya/lib/python3.7/site-packages/dask/local.py in get_async(apply_async, num_workers, dsk, result, cache, get_id, rerun_exceptions_locally, pack_exception, raise_exception, callbacks, dumps, loads, **kwargs)
#     484                         _execute_task(task, data)  # Re-execute locally
#     485                     else:
# --> 486                         raise_exception(exc, tb)
#     487                 res, worker_id = loads(res_info)
#     488                 state["cache"][key] = res
#
# ~/anaconda3/envs/pya/lib/python3.7/site-packages/dask/local.py in reraise(exc, tb)
#     314     if exc.__traceback__ is not tb:
#     315         raise exc.with_traceback(tb)
# --> 316     raise exc
#     317
#     318
#
# ~/anaconda3/envs/pya/lib/python3.7/site-packages/dask/local.py in execute_task(key, task_info, dumps, loads, get_id, pack_exception)
#     220     try:
#     221         task, data = loads(task_info)
# --> 222         result = _execute_task(task, data)
#     223         id = get_id()
#     224         result = dumps((result, id))
#
# ~/anaconda3/envs/pya/lib/python3.7/site-packages/dask/core.py in _execute_task(arg, cache, dsk)
#     117         func, args = arg[0], arg[1:]
#     118         args2 = [_execute_task(a, cache) for a in args]
# --> 119         return func(*args2)
#     120     elif not ishashable(arg):
#     121         return arg
#
# ~/anaconda3/envs/pya/lib/python3.7/site-packages/dask/array/core.py in getter(a, b, asarray, lock)
#     102         lock.acquire()
#     103     try:
# --> 104         c = a[b]
#     105         if asarray:
#     106             c = np.asarray(c)
#
# ~/anaconda3/envs/pya/lib/python3.7/site-packages/iris/fileformats/netcdf.py in __getitem__(self, keys)
#     389
#     390     def __getitem__(self, keys):
# --> 391         dataset = netCDF4.Dataset(self.path)
#     392         try:
#     393             variable = dataset.variables[self.variable_name]
#
# netCDF4/_netCDF4.pyx in netCDF4._netCDF4.Dataset.__init__()
#
# netCDF4/_netCDF4.pyx in netCDF4._netCDF4._ensure_nc_success()
#
# FileNotFoundError: [Errno 2] No such file or directory: b'/lustre/storeA/project/aerocom/aerocom-users-database/AEROCOM-PHASE-III-2019/BCC-CUACE_AP3-HIST/renamed/aerocom3_BCC-CUACE_HIST_od550aer_Surface_1850_monthly.nc'

# %%
sns.set()
sns.set_context("paper")
sns.color_palette("muted")
# Out:
# [(0.2823529411764706, 0.47058823529411764, 0.8156862745098039),
#  (0.9333333333333333, 0.5215686274509804, 0.2901960784313726),
#  (0.41568627450980394, 0.8, 0.39215686274509803),
#  (0.8392156862745098, 0.37254901960784315, 0.37254901960784315),
#  (0.5843137254901961, 0.4235294117647059, 0.7058823529411765),
#  (0.5490196078431373, 0.3803921568627451, 0.23529411764705882),
#  (0.8627450980392157, 0.49411764705882355, 0.7529411764705882),
#  (0.4745098039215686, 0.4745098039215686, 0.4745098039215686),
#  (0.8352941176470589, 0.7333333333333333, 0.403921568627451),
#  (0.5098039215686274, 0.7764705882352941, 0.8862745098039215)]

# %%
fig, ax = plt.subplots(figsize=(9, 3), dpi=100, facecolor='w', edgecolor='k')
models = list(MOD_MAP.keys())
for model in models:
    
    #monthly values
    mx = js2date(MOD_MAP[model]['WORLD']['trends']['monthly']['jsdate'])
    my = MOD_MAP[model]['WORLD']['trends']['monthly']['data']
    #yealry values
    yx = js2date(MOD_MAP[model]['WORLD']['trends']['yearly']['jsdate'])
    yy = MOD_MAP[model]['WORLD']['trends']['yearly']['data']
    
    if yx[0]<datetime.datetime(1900, 1, 1, 1, 0):
        color = 'black' #get_color2_mod(model)
        plt.plot(mx, my, color=color, lw=0.5, alpha=.1, zorder=3)
        plt.plot(yx, yy, color=color, label=get_all_mods()[model]['name'], lw=1, alpha=.5, zorder=5)

plt.ylabel('Global AOD')


#available observations
nobs = OBS_DF['WORLD'].groupby(pd.Grouper(freq='A')).mean().count(axis=1)
ox = nobs.index
oy = nobs.values
#set new axis
ax2 = ax.twinx()
color = 'tab:blue'
ax2.set_ylabel('Available observations', color=color)  # we already handled the x-label with ax1
ax2.bar(ox, oy, width=1, color=color, alpha=.3, linewidth=0, zorder=4)
ax2.tick_params(axis='y', labelcolor=color)
ax2.grid(False)

#highlight study period
plt.axvspan(datetime.datetime(2000, 1, 1, 1, 0),datetime.datetime(2015, 1, 1, 1, 0), facecolor='gray', alpha=0.20, zorder=0)

# %%
# calculates monthly averages for the plots
dcount = med.groupby(pd.Grouper(freq='M')).count()
mmed = med.groupby(pd.Grouper(freq='M')).mean().where(
dcount >= params['min_dim'])
